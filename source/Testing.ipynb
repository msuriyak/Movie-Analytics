# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('results', delimiter=';', header=[0, 1], index_col=0)
data.columns = pd.MultiIndex.from_tuples(data.columns)

# %%
data.head()
# Out:
#           imdb                                                           \
#   Release Date Gross Rating Country                              Writer
# 0   1951-08-14  None    7.8     USA  Theodore Dreiser | Patrick Kearney
# 1   1951-07-16  None    7.4     USA   Robert Buckner | Baynard Kendrick
# 2         1951  None    7.6     USA        Philip Yordan | Robert Wyler
# 3   1952-11-13  None    7.2     USA       John Lee Mahin | S.N. Behrman
# 4   1951-12-01  None    8.0     USA     Tennessee Williams | Oscar Saul
#
#                                                                   \
#                       Title      Budget  Year           Language
# 0        A Place in the Sun  $2,295,304  1951            English
# 1            Bright Victory        None  1951            English
# 2           Detective Story        None  1951            English
# 3                 Quo Vadis  $7,623,000  1951            English
# 4  A Streetcar Named Desire  $1,800,000  1951  English | Spanish
#
# ...
