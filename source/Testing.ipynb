# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('data_try_1', sep='\t', header=[0, 1], index_col=0)
data.columns = pd.MultiIndex.from_tuples(data.columns)

# %%
data.head()
# Out:
#              imdb                                                            \
#   Opening weekend       Cast       Release Date                       Title
# 1          96 min  tt0043361            English              Bright Victory
# 2         103 min  tt0043465            English             Detective Story
# 3         171 min  tt0043949            English                   Quo Vadis
# 4         122 min  tt0044081  English | Spanish    A Streetcar Named Desire
# 5         152 min  tt0044672  English | Russian  The Greatest Show on Earth
#
#                                                                              \
#   Metascore Rating   UID                                              Gross
# 1       7.4   None  None  Arthur Kennedy | Peggy Dow | Julie Adams | Jam...
# 2       7.6   None  None  Kirk Douglas | Eleanor Parker | William Bendix...
# 3       7.2   None  None  Robert Taylor | Deborah Kerr | Leo Genn | Pete...
# ...
